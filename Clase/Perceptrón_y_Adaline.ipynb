# %% [markdown]
# # Perceptrón

# %% [markdown]
# El perceptrón es uno de los modelos más simples de redes neuronales. Es un clasificador binario que toma una decisión lineal para separar dos clases. Utiliza una función de activación escalón para determinar la salida. Debería ofrecer una precisión alta si los datos son linealmente separables.
#
# En este caso, podemos usar datos simples como la clasificación de transacciones contables en "gastos" (0) e e"ingresos" (1).
#
# | Montos | Tipo |
# |--------|------|
# | 500    | 1    | (Ingreso)
# | 300    | 1    | (Ingreso)
# | -200   | 0    | (Gasto)
# | -150   | 0    | (Gasto)

# %% [markdown]
# ## Implementación en `tensorflow`

# %%
import tensorflow as tf
import numpy as np

# Datos del ejemplo, creamos los datos de entrada (montos) y la etiqueta (tipos)
montos = np.array([[500], [300], [-200], [-150]], dtype=np.float32)
tipos = np.array([[1], [1], [0], [0]], dtype=np.float32)

# Creamos el modelo de perceptrón. units el número de neuronas. El perceptrón tiene 1
# La función de activación debería ser escalón, pero keras no la tiene...usaremos la más similar
modelo = tf.keras.Sequential([tf.keras.layers.Dense(units=1, activation = 'sigmoid')])

# Compilamos el modelo. El optimizador será el que se encargue de actualizar
# los pesos, en este caso será gradiente descendente estocástico
modelo.compile(optimizer = 'sgd', loss = 'binary_crossentropy',
               metrics = ['accuracy'])

# Entrenamos el modelo modelo.
# Una época significa entrenar la red neuronal con todos los datos
# de entrenamiento para un ciclo . En una época, usamos todos los datos exactamente una vez.
# Un pase hacia adelante para el cálculo de la salida y un pase hacia atrás para el cálculo del error,
# juntos se cuentan como un pase.
# Una época se compone de uno o más lotes, donde usamos una parte del conjunto de datos para
# entrenar la red neuronal.
modelo.fit(montos, tipos, epochs=10)

# Calculamos la precisión (accuracy)
predicted = modelo.predict(montos)
predicted_classes = (predicted >= 0.5).astype(int)  # Umbral para clasificación (0.5))
accuracy = np.mean(predicted_classes.flatten() == tipos.flatten())
print(accuracy)

# Evaluamos el modelo con el error de entrenamiento
predicted = modelo.predict(montos)
predicted_classes = (predicted >= 0.5).astype(int)  # Umbral para clasificación (0.5))
print(predicted_classes)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[1]
#  [1]
#  [0]
#  [0]]

# %% [markdown]
# ## Implementación en `Pytorch`

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# hacemos tensores con los datos de entrada y la variable objetivo
X = torch.tensor(montos, dtype=torch.float32)

y = torch.tensor(tipos, dtype=torch.float32)

# Hacemos la clase perceptrón. En el __init__ están los atributos de la clase
# las demás funciones son llamados métodos
class Perceptron(nn.Module):
    def __init__(self):
        super(Perceptron, self).__init__()
        self.linear = nn.Linear(1, 1) #define las entradas y las neuronas en cada capa.
                                      #tenemos solo una caracterítica a la entrada

    def forward(self, x): #es el método para aplicar un sigmoide a la salida. La idea sería un escalón
        return torch.sigmoid(self.linear(x))

# Definimos un objeto de la clase Perceptrón
model_pytorch = Perceptron()

# Establecemos el criterio de pérdida (Binary Cross Entropy Loss) y
# el optimizador (gradiente descendente)
criterion = nn.BCELoss()
optimizer = optim.SGD(model_pytorch.parameters(), lr=0.01) #lr es la tasa de aprendizaje

# Hacemos el entrenamiento con 100 épocas
for epoch in range(100):
    optimizer.zero_grad() # limpiar los gradientes anteriores
    outputs = model_pytorch(X) #entrenamos
    loss = criterion(outputs, y) #calculamos la pérdida
    loss.backward() #hacemos el backward para calcular los nuevos gradientes
    optimizer.step() #ajustamos los pesos del modelo usando los gradientes calculados en loss.backward()

# Evaluamos la red con el mismo conjunto de entrenamiento (acierto de entrenamiento = 1- error de entrenamiento)
with torch.no_grad():
    predicted = model_pytorch(X) #realizamos la predicción
    predicted_classes = (predicted >= 0.5).float() #establecemos el umbral
    accuracy = (predicted_classes.eq(y).sum().item()) / y.size(0) #calculamos el acierto
    print(f'Perceptrón (PyTorch) - Precisión: {accuracy*100:.2f}%')
# Out:
# Perceptrón (PyTorch) - Precisión: 100.00%

# %% [markdown]
# # Adaline  (ADAptive LInear NEuron)

# %% [markdown]
# Adaline es similar al perceptrón, pero en lugar de usar una función de activación escalón, utiliza una función de activación lineal y minimiza el error cuadrático medio. Esto lo hace más adecuado para problemas de regresión y clasificación con gradiente descendente.
#
# Vamos a crear un conjunto de datos relacionado con la aprobación de préstamos. Las características serán:
#
# - Ingresos mensuales (en miles de dólares)
# - Deuda actual (en miles de dólares)
# - Historial de crédito (1: bueno, 0: malo)
#
# |Ingresos|	Deuda	|Historial	|Aprobado|
# |--------|--------|-----------|--------|
# |5	|1.5	|1|	1|
# |3	|2.0	|0	|0|
# |4	|1.0	|1	|1|
# |2	|2.5	|0	|0|
# |6	|1.2	|1	|1|
# |3.5|	2.2	|0	|0|

# %%
# Cargamos las librería
import tensorflow as tf
import numpy as np

# Definimos la matriz de datos o características
X = np.array([
    [5, 1.5, 1],
    [3, 2.0, 0],
    [4, 1.0, 1],
    [2, 2.5, 0],
    [6, 1.2, 1],
    [3.5, 2.2, 0]
], dtype=float)

# Nuestra característica objetivo será la columna Aprobado
y = np.array([1, 0, 1, 0, 1, 0], dtype=float)

# %% [markdown]
# ## Implementación con `tensorflow`

# %%
# Instanciamos el modelo Adaline. Aunque no existe directamente, se puede generar con la función de activación lineal.
# Tenemos tres entradas (Ingreso, Deuda, Historial)
model_adaline = tf.keras.Sequential([tf.keras.layers.Dense(1, activation='linear', input_shape=(3,))])

# Compilamos nuestro modelo. Para Adaline la función de pérdida está dada por el MSE
model_adaline.compile(optimizer='sgd',
                      loss='mean_squared_error',
                      metrics=['mean_squared_error'])

# Entrenamos el modelo. Al establecer el parámetro 'verbose' en  0, 1 o 2, simplemente dices cómo deseas "ver" el progreso del entrenamiento para cada época.
model_adaline.fit(X, y, epochs=200, verbose=1)

# Evaluamos el modelo con el error de entrenamiento
mse = model_adaline.evaluate(X, y, verbose=0)
print(f'Adaline - MSE: {mse[1]:.4f}')
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step - loss: 0.3204 - mean_squared_error: 0.3204
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3072 - mean_squared_error: 0.3072
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2945 - mean_squared_error: 0.2945
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2824 - mean_squared_error: 0.2824
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2708 - mean_squared_error: 0.2708
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2596 - mean_squared_error: 0.2596
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2490 - mean_squared_error: 0.2490
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.2388 - mean_squared_error: 0.2388
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2290 - mean_squared_error: 0.2290
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2196 - mean_squared_error: 0.2196
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2106 - mean_squared_error: 0.2106
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2020 - mean_squared_error: 0.2020
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1938 - mean_squared_error: 0.1938
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1859 - mean_squared_error: 0.1859
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1783 - mean_squared_error: 0.1783
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1710 - mean_squared_error: 0.1710
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1641 - mean_squared_error: 0.1641
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1574 - mean_squared_error: 0.1574
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1511 - mean_squared_error: 0.1511
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1450 - mean_squared_error: 0.1450
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1391 - mean_squared_error: 0.1391
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1335 - mean_squared_error: 0.1335
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1281 - mean_squared_error: 0.1281
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1230 - mean_squared_error: 0.1230
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1181 - mean_squared_error: 0.1181
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1133 - mean_squared_error: 0.1133
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1088 - mean_squared_error: 0.1088
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1045 - mean_squared_error: 0.1045
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1003 - mean_squared_error: 0.1003
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0963 - mean_squared_error: 0.0963
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0925 - mean_squared_error: 0.0925
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0889 - mean_squared_error: 0.0889
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0854 - mean_squared_error: 0.0854
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0820 - mean_squared_error: 0.0820
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0788 - mean_squared_error: 0.0788
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0757 - mean_squared_error: 0.0757
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0728 - mean_squared_error: 0.0728
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0699 - mean_squared_error: 0.0699
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0672 - mean_squared_error: 0.0672
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0646 - mean_squared_error: 0.0646
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0622 - mean_squared_error: 0.0622
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0598 - mean_squared_error: 0.0598
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0575 - mean_squared_error: 0.0575
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0553 - mean_squared_error: 0.0553
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0532 - mean_squared_error: 0.0532
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0512 - mean_squared_error: 0.0512
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0493 - mean_squared_error: 0.0493
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0474 - mean_squared_error: 0.0474
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0457 - mean_squared_error: 0.0457
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0440 - mean_squared_error: 0.0440
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0423 - mean_squared_error: 0.0423
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0408 - mean_squared_error: 0.0408
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0393 - mean_squared_error: 0.0393
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0379 - mean_squared_error: 0.0379
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0365 - mean_squared_error: 0.0365
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0352 - mean_squared_error: 0.0352
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0339 - mean_squared_error: 0.0339
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0327 - mean_squared_error: 0.0327
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0316 - mean_squared_error: 0.0316
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0305 - mean_squared_error: 0.0305
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0294 - mean_squared_error: 0.0294
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0284 - mean_squared_error: 0.0284
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0274 - mean_squared_error: 0.0274
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0265 - mean_squared_error: 0.0265
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0256 - mean_squared_error: 0.0256
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0247 - mean_squared_error: 0.0247
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0239 - mean_squared_error: 0.0239
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0231 - mean_squared_error: 0.0231
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0224 - mean_squared_error: 0.0224
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0217 - mean_squared_error: 0.0217
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0210 - mean_squared_error: 0.0210
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0203 - mean_squared_error: 0.0203
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0197 - mean_squared_error: 0.0197
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0191 - mean_squared_error: 0.0191
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0179 - mean_squared_error: 0.0179
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0159 - mean_squared_error: 0.0159
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0154 - mean_squared_error: 0.0154
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0142 - mean_squared_error: 0.0142
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0138 - mean_squared_error: 0.0138
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0121 - mean_squared_error: 0.0121
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0096 - mean_squared_error: 0.0096
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0087 - mean_squared_error: 0.0087
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0084 - mean_squared_error: 0.0084
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0082 - mean_squared_error: 0.0082
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0080 - mean_squared_error: 0.0080
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0078 - mean_squared_error: 0.0078
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0077 - mean_squared_error: 0.0077
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0076 - mean_squared_error: 0.0076
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0071 - mean_squared_error: 0.0071
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0069 - mean_squared_error: 0.0069
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0068 - mean_squared_error: 0.0068
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0066 - mean_squared_error: 0.0066
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Adaline - MSE: 0.0044

# %% [markdown]
# ## Implementación con `Pytorch`

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Declaramos los datos como tensores, tanto en la matriz de características
X = torch.tensor([
    [5, 1.5, 1],
    [3, 2.0, 0],
    [4, 1.0, 1],
    [2, 2.5, 0],
    [6, 1.2, 1],
    [3.5, 2.2, 0]
], dtype=torch.float32)


# como la de la característica objetivo
y = torch.tensor([[1], [0], [1], [0], [1], [0]], dtype=torch.float32)

# %%
# Hacemos algo muy similar al caso del Perceptrón. Creamos la clase Adaline que
# hereda de nn.Module.

class Adaline(nn.Module):
    def __init__(self):
        super(Adaline, self).__init__()
        self.linear = nn.Linear(3, 1) #tenemos 3 entradas y solo una neurona operando

    def forward(self, x):
        return self.linear(x) #tenemos la función de activación lineal a la salida

model_adaline_pytorch = Adaline() #creamos el objeto model_adaline_pytorch de la clase Adaline

# Definimos la función de pérdida con el MSE y el optimizador de gradiente descendente estocástico
criterion_adaline = nn.MSELoss()
optimizer_adaline = optim.SGD(model_adaline_pytorch.parameters(), lr=0.01) #como hiperpámetro está la tasa de aprendizaje

# Entrenamos el modelo como en el caso del perceptrón
for epoch in range(100):
    optimizer_adaline.zero_grad()
    outputs = model_adaline_pytorch(X)
    loss = criterion_adaline(outputs, y)
    loss.backward()
    optimizer_adaline.step()

# Evaluamos el modelo con el error de entrenamiento y el MSE
with torch.no_grad():
    mse = criterion_adaline(model_adaline_pytorch(X), y)
    print(f'Adaline (PyTorch) - MSE: {mse.item():.4f}')
# Out:
# Adaline (PyTorch) - MSE: 0.0781
