# %% [markdown]
# #Instrucciones:
# Integración de datos multidimensional

# %%
#importamos las librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import plotly.express as px
import plotly.graph_objects as go

# %%
#Conectamos con Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Cargamos los archivos
amazon = pd.read_csv('/content/drive/MyDrive/Integración de Datos y Prospectiva/Reto final/Amazon.csv')
disney = pd.read_csv('/content/drive/MyDrive/Integración de Datos y Prospectiva/Reto final/Disney+.csv')
hbo = pd.read_csv('/content/drive/MyDrive/Integración de Datos y Prospectiva/Reto final/HBO+.csv')
netflix = pd.read_csv('/content/drive/MyDrive/Integración de Datos y Prospectiva/Reto final/Netflix.csv')
